# %%
import pandas as pd
import numpy as np
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from scripts.load import load_raw
from scripts.config import DATA_PROCESSED_PATH, VEL_MIN, VEL_MAX, VEL_NORMAL_UMBRAL, \
RESULTS_PATH, RESULTS_TABLES, MOTOR_VELOCIDAD_TOTAL, MOTOR_VELOCIDAD_SEG, BINARY_COLS

# %%
# Parámetros/constantes
CSV_NAME = "data-neuro-tts.csv"
UMBRAL_VEL = VEL_NORMAL_UMBRAL

# %%
# Carga de datos
df = load_raw(CSV_NAME)
print(f'El dataset tiene {df.shape[0]} filas y {df.shape[1]} columnas.')
# Out:
# El dataset tiene 49 filas y 57 columnas.

# %%
df.head(3) # Primeros 3 registros
# Out:
#           id  tts_pie_derecho  tts_pie_izquierdo  radiculopatia_s1_dch  \
# 0  Y3870090D                1                  0                     0
# 1  50297827R                1                  1                     1
# 2  50735751M                1                  0                     1
#
#    radiculopatia_s1_izq  polineuropatia  arcada_del_soleo  pre_fecha  \
# 0                     0               0                 0 2022-12-21
# 1                     1               0                 0 2023-03-18
# 2                     0               0                 0 2023-01-23
#
#    pre_dch_motor_velocidad_total  pre_dch_motor_amplitud_total  ...  \
# 0                           52.2                          23.6  ...
# 1                            NaN                           NaN  ...
# 2                           48.2                           8.9  ...
#
#    post_dch_sensitivo_velocidad_n_calcaneo_medial  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#    post_dch_sensitivo_amplitud_n_calcaneo_medial  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    post_izq_sensitivo_velocidad_n_plantar_medial  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    post_izq_sensitivo_amplitud_n_plantar_medial  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
#    post_izq_sensitivo_velocidad_n_plantar_lateral  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#    post_izq_sensitivo_amplitud_n_plantar_lateral  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    post_izq_sensitivo_velocidad_n_baxter  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
#
#    post_izq_sensitivo_amplitud_n_baxter  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#    post_izq_sensitivo_velocidad_n_calcaneo_medial  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
#    post_izq_sensitivo_amplitud_n_calcaneo_medial
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
# [3 rows x 57 columns]

# %%
df.tail(3) # Últimos 3 registros
# Out:
#            id  tts_pie_derecho  tts_pie_izquierdo  radiculopatia_s1_dch  \
# 46  15374842D                1                  0                     0
# 47  01831288M                1                  1                     0
# 48  75914456N                0                  1                     0
#
#     radiculopatia_s1_izq  polineuropatia  arcada_del_soleo  pre_fecha  \
# 46                     0               0                 0 2025-07-03
# 47                     1               0                 0 2024-06-26
# 48                     0               0                 1 2024-06-05
#
#     pre_dch_motor_velocidad_total  pre_dch_motor_amplitud_total  ...  \
# 46                           53.3                           7.9  ...
# 47                           52.5                          15.7  ...
# 48                            NaN                           NaN  ...
#
#     post_dch_sensitivo_velocidad_n_calcaneo_medial  \
# 46                                             NaN
# 47                                             NaN
# 48                                             NaN
#
#     post_dch_sensitivo_amplitud_n_calcaneo_medial  \
# 46                                            NaN
# 47                                            NaN
# 48                                            NaN
#
#     post_izq_sensitivo_velocidad_n_plantar_medial  \
# 46                                            NaN
# 47                                            NaN
# 48                                           50.6
#
#     post_izq_sensitivo_amplitud_n_plantar_medial  \
# 46                                           NaN
# 47                                           NaN
# 48                                           1.5
#
#     post_izq_sensitivo_velocidad_n_plantar_lateral  \
# 46                                             NaN
# 47                                             NaN
# 48                                            50.0
#
#     post_izq_sensitivo_amplitud_n_plantar_lateral  \
# 46                                            NaN
# 47                                            NaN
# 48                                            0.3
#
#     post_izq_sensitivo_velocidad_n_baxter  \
# 46                                    NaN
# 47                                    NaN
# 48                                    NaN
#
#     post_izq_sensitivo_amplitud_n_baxter  \
# 46                                   NaN
# 47                                   NaN
# 48                                   NaN
#
#     post_izq_sensitivo_velocidad_n_calcaneo_medial  \
# 46                                             NaN
# 47                                             NaN
# 48                                             NaN
#
#     post_izq_sensitivo_amplitud_n_calcaneo_medial
# 46                                            NaN
# 47                                            NaN
# 48                                            NaN
#
# [3 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 57 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              49 non-null     object
#  1   tts_pie_derecho                                 49 non-null     Int64
#  2   tts_pie_izquierdo                               49 non-null     Int64
#  3   radiculopatia_s1_dch                            49 non-null     Int64
#  4   radiculopatia_s1_izq                            49 non-null     Int64
#  5   polineuropatia                                  49 non-null     Int64
#  6   arcada_del_soleo                                49 non-null     Int64
#  7   pre_fecha                                       49 non-null     datetime64[ns]
#  8   pre_dch_motor_velocidad_total                   38 non-null     float64
#  9   pre_dch_motor_amplitud_total                    38 non-null     float64
#  10  pre_dch_motor_velocidad_segmentario             42 non-null     float64
#  11  pre_dch_motor_amplitud_segmentario              42 non-null     float64
#  12  pre_izq_motor_velocidad_total                   32 non-null     float64
#  13  pre_izq_motor_amplitud_total                    32 non-null     float64
#  14  pre_izq_motor_velocidad_segmentario             35 non-null     float64
#  15  pre_izq_motor_amplitud_segmentario              35 non-null     float64
#  16  pre_dch_sensitivo_velocidad_n_plantar_medial    16 non-null     float64
#  17  pre_dch_sensitivo_amplitud_n_plantar_medial     16 non-null     float64
#  18  pre_dch_sensitivo_velocidad_n_plantar_lateral   15 non-null     float64
#  19  pre_dch_sensitivo_amplitud_n_plantar_lateral    15 non-null     float64
#  20  pre_dch_sensitivo_velocidad_n_baxter            4 non-null      float64
#  21  pre_dch_sensitivo_amplitud_n_baxter             4 non-null      float64
#  22  pre_dch_sensitivo_velocidad_n_calcaneo_medial   2 non-null      float64
#  23  pre_dch_sensitivo_amplitud_n_calcaneo_medial    2 non-null      float64
#  24  pre_izq_sensitivo_velocidad_n_plantar_medial    16 non-null     float64
#  25  pre_izq_sensitivo_amplitud_n_plantar_medial     16 non-null     float64
#  26  pre_izq_sensitivo_velocidad_n_plantar_lateral   12 non-null     float64
#  27  pre_izq_sensitivo_amplitud_n_plantar_lateral    12 non-null     float64
#  28  pre_izq_sensitivo_velocidad_n_baxter            5 non-null      float64
#  29  pre_izq_sensitivo_amplitud_n_baxter             5 non-null      float64
#  30  pre_izq_sensitivo_velocidad_n_calcaneo_medial   2 non-null      float64
#  31  pre_izq_sensitivo_amplitud_n_calcaneo_medial    2 non-null      float64
#  32  post_fecha                                      27 non-null     datetime64[ns]
#  33  post_dch_motor_velocidad_total                  12 non-null     float64
#  34  post_dch_motor_amplitud_total                   12 non-null     float64
#  35  post_dch_motor_velocidad_segmentario            22 non-null     float64
#  36  post_dch_motor_amplitud_segmentario             21 non-null     float64
#  37  post_izq_motor_velocidad_total                  11 non-null     float64
#  38  post_izq_motor_amplitud_total                   11 non-null     float64
#  39  post_izq_motor_velocidad_segmentario            18 non-null     float64
#  40  post_izq_motor_amplitud_segmentario             18 non-null     float64
#  41  post_dch_sensitivo_velocidad_n_plantar_medial   2 non-null      float64
#  42  post_dch_sensitivo_amplitud_n_plantar_medial    2 non-null      float64
#  43  post_dch_sensitivo_velocidad_n_plantar_lateral  4 non-null      float64
#  44  post_dch_sensitivo_amplitud_n_plantar_lateral   4 non-null      float64
#  45  post_dch_sensitivo_velocidad_n_baxter           1 non-null      float64
#  46  post_dch_sensitivo_amplitud_n_baxter            1 non-null      float64
#  47  post_dch_sensitivo_velocidad_n_calcaneo_medial  0 non-null      float64
#  48  post_dch_sensitivo_amplitud_n_calcaneo_medial   0 non-null      float64
#  49  post_izq_sensitivo_velocidad_n_plantar_medial   5 non-null      float64
#  50  post_izq_sensitivo_amplitud_n_plantar_medial    5 non-null      float64
#  51  post_izq_sensitivo_velocidad_n_plantar_lateral  4 non-null      float64
#  52  post_izq_sensitivo_amplitud_n_plantar_lateral   4 non-null      float64
#  53  post_izq_sensitivo_velocidad_n_baxter           1 non-null      float64
#  54  post_izq_sensitivo_amplitud_n_baxter            1 non-null      float64
#  55  post_izq_sensitivo_velocidad_n_calcaneo_medial  1 non-null      float64
#  56  post_izq_sensitivo_amplitud_n_calcaneo_medial   1 non-null      float64
# dtypes: Int64(6), datetime64[ns](2), float64(48), object(1)
# memory usage: 22.2+ KB

# %% [markdown]
# ## Duplicados

# %%
# Verificar si existen duplicados
dup_mask = df["id"].duplicated(keep=False)
n_ids_duplicated = df.loc[dup_mask, "id"].nunique()
n_rows_dup_id = dup_mask.sum()

print(f"IDs duplicados (n IDs): {n_ids_duplicated}")
print(f"Filas con id duplicado (n filas): {n_rows_dup_id}")
# Out:
# IDs duplicados (n IDs): 0
# Filas con id duplicado (n filas): 0

# %% [markdown]
# ## Valores faltantes

# %%
missing_pct = df.isna().mean().sort_values(ascending=False) * 100
missing_tbl = missing_pct.to_frame("pct_missing").round(2)
display(missing_tbl.head(40))
# Out:
#                                                 pct_missing
# post_dch_sensitivo_amplitud_n_calcaneo_medial        100.00
# post_dch_sensitivo_velocidad_n_calcaneo_medial       100.00
# post_izq_sensitivo_amplitud_n_calcaneo_medial         97.96
# post_dch_sensitivo_velocidad_n_baxter                 97.96
# post_dch_sensitivo_amplitud_n_baxter                  97.96
# post_izq_sensitivo_velocidad_n_baxter                 97.96
# post_izq_sensitivo_amplitud_n_baxter                  97.96
# post_izq_sensitivo_velocidad_n_calcaneo_medial        97.96
# pre_dch_sensitivo_velocidad_n_calcaneo_medial         95.92
# post_dch_sensitivo_velocidad_n_plantar_medial         95.92
# pre_dch_sensitivo_amplitud_n_calcaneo_medial          95.92
# pre_izq_sensitivo_velocidad_n_calcaneo_medial         95.92
# pre_izq_sensitivo_amplitud_n_calcaneo_medial          95.92
# post_dch_sensitivo_amplitud_n_plantar_medial          95.92
# pre_dch_sensitivo_amplitud_n_baxter                   91.84
# pre_dch_sensitivo_velocidad_n_baxter                  91.84
# post_izq_sensitivo_amplitud_n_plantar_lateral         91.84
# post_izq_sensitivo_velocidad_n_plantar_lateral        91.84
# post_dch_sensitivo_amplitud_n_plantar_lateral         91.84
# post_dch_sensitivo_velocidad_n_plantar_lateral        91.84
# pre_izq_sensitivo_amplitud_n_baxter                   89.80
# post_izq_sensitivo_velocidad_n_plantar_medial         89.80
# post_izq_sensitivo_amplitud_n_plantar_medial          89.80
# pre_izq_sensitivo_velocidad_n_baxter                  89.80
# post_izq_motor_velocidad_total                        77.55
# post_izq_motor_amplitud_total                         77.55
# pre_izq_sensitivo_velocidad_n_plantar_lateral         75.51
# pre_izq_sensitivo_amplitud_n_plantar_lateral          75.51
# post_dch_motor_velocidad_total                        75.51
# post_dch_motor_amplitud_total                         75.51
# pre_dch_sensitivo_amplitud_n_plantar_lateral          69.39
# pre_dch_sensitivo_velocidad_n_plantar_lateral         69.39
# pre_izq_sensitivo_velocidad_n_plantar_medial          67.35
# pre_dch_sensitivo_velocidad_n_plantar_medial          67.35
# pre_dch_sensitivo_amplitud_n_plantar_medial           67.35
# pre_izq_sensitivo_amplitud_n_plantar_medial           67.35
# post_izq_motor_velocidad_segmentario                  63.27
# post_izq_motor_amplitud_segmentario                   63.27
# post_dch_motor_amplitud_segmentario                   57.14
# post_dch_motor_velocidad_segmentario                  55.10

# %%
# Guardar para trazabilidad
RESULTS_TABLES.mkdir(parents=True, exist_ok=True)
missing_tbl.to_csv(RESULTS_TABLES / "porcentajes_valores_faltantes.csv")

# %% [markdown]
# ## Análisis descriptivo general

# %%
n_estudios = df[["tts_pie_derecho","tts_pie_izquierdo"]].agg(["sum", "count"])
n_pacientes = df['id'].nunique()

# %%
n_estudios
# Out:
#        tts_pie_derecho  tts_pie_izquierdo
# sum                 42                 32
# count               49                 49

# %%
print(f"Total de pacientes: {n_pacientes}")
# Out:
# Total de pacientes: 49

# %%
# columnas motor velocidad total/segmentario por lado y tiempo
COL_PRE_DCH_VEL_TOT = "pre_dch_motor_velocidad_total"
COL_POST_DCH_VEL_TOT = "post_dch_motor_velocidad_total"
COL_PRE_IZQ_VEL_TOT = "pre_izq_motor_velocidad_total"
COL_POST_IZQ_VEL_TOT = "post_izq_motor_velocidad_total"

COL_PRE_DCH_VEL_SEG = "pre_dch_motor_velocidad_segmentario"
COL_POST_DCH_VEL_SEG = "post_dch_motor_velocidad_segmentario"
COL_PRE_IZQ_VEL_SEG = "pre_izq_motor_velocidad_segmentario"
COL_POST_IZQ_VEL_SEG = "post_izq_motor_velocidad_segmentario"

cols_desc = [
    COL_PRE_DCH_VEL_TOT, COL_POST_DCH_VEL_TOT, 
    COL_PRE_IZQ_VEL_TOT, COL_POST_IZQ_VEL_TOT,
    COL_PRE_DCH_VEL_SEG, COL_POST_DCH_VEL_SEG, 
    COL_PRE_IZQ_VEL_SEG, COL_POST_IZQ_VEL_SEG
]

# %%
desc_motor_vel = df[cols_desc].describe().T
desc_motor_vel
# Out:
#                                       count       mean       std   min  \
# pre_dch_motor_velocidad_total          38.0  50.028947  4.426695  42.2
# post_dch_motor_velocidad_total         12.0  51.350000  4.224496  45.9
# pre_izq_motor_velocidad_total          32.0  49.278125  3.729545  43.0
# post_izq_motor_velocidad_total         11.0  49.645455  6.956776  35.7
# pre_dch_motor_velocidad_segmentario    42.0  39.347619  5.137060  29.7
# post_dch_motor_velocidad_segmentario   22.0  44.909091  4.034837  36.8
# pre_izq_motor_velocidad_segmentario    35.0  39.717143  5.311779  27.1
# post_izq_motor_velocidad_segmentario   18.0  48.505556  4.784592  39.3
#
#                                          25%    50%     75%   max
# pre_dch_motor_velocidad_total         46.800  48.90  53.100  61.2
# post_dch_motor_velocidad_total        48.175  50.00  54.500  58.0
# pre_izq_motor_velocidad_total         46.450  49.15  51.625  58.3
# post_izq_motor_velocidad_total        47.000  49.30  51.700  64.5
# pre_dch_motor_velocidad_segmentario   36.400  39.05  41.625  53.6
# post_dch_motor_velocidad_segmentario  43.475  45.20  46.950  52.2
# pre_izq_motor_velocidad_segmentario   36.550  39.40  43.500  50.7
# post_izq_motor_velocidad_segmentario  45.725  47.70  52.475  57.1

# %%
# Guardar analsis descriptivo
desc_motor_vel.to_csv(RESULTS_TABLES / "analisis_descriptivo_motor_velocidad.csv", index=False)

# %%
# Tiempos entre estudios pre y post
df["dias_entre_estudios"] = (df["post_fecha"] - df["pre_fecha"]).dt.days
display(df["dias_entre_estudios"].describe())
# Out:
# count     27.000000
# mean     339.407407
# std      117.024409
# min       60.000000
# 25%      310.500000
# 50%      328.000000
# 75%      349.000000
# max      741.000000
# Name: dias_entre_estudios, dtype: float64

# %%
df["semanas_entre_estudios"] = [(col / 7) for col in df["dias_entre_estudios"]]
display(df["semanas_entre_estudios"].describe())
# Out:
# count     27.000000
# mean      48.486772
# std       16.717773
# min        8.571429
# 25%       44.357143
# 50%       46.857143
# 75%       49.857143
# max      105.857143
# Name: semanas_entre_estudios, dtype: float64

# %% [markdown]
# ## Posibles falsos negativos y conteos
#
# `fn_*` = falso negativo (total normal ≥ 45 y segmentario patológico < 45).

# %%
df["fn_pre_dch"] = (df[COL_PRE_DCH_VEL_TOT] >= UMBRAL_VEL) & (df[COL_PRE_DCH_VEL_SEG] < UMBRAL_VEL)
df["fn_pre_izq"] = (df[COL_PRE_IZQ_VEL_TOT] >= UMBRAL_VEL) & (df[COL_PRE_IZQ_VEL_SEG] < UMBRAL_VEL)
df["fn_post_dch"] = (df[COL_POST_DCH_VEL_TOT] >= UMBRAL_VEL) & (df[COL_POST_DCH_VEL_SEG] < UMBRAL_VEL)
df["fn_post_izq"] = (df[COL_POST_IZQ_VEL_TOT] >= UMBRAL_VEL) & (df[COL_POST_IZQ_VEL_SEG] < UMBRAL_VEL)

fn_counts = pd.DataFrame({
    "lado": ["derecho", "izquierdo"],
    "n_fn_pre": [
        df["fn_pre_dch"].sum(skipna=True),
        df["fn_pre_izq"].sum(skipna=True),
    ],
    "n_fn_post": [
        df["fn_post_dch"].sum(skipna=True),
        df["fn_post_izq"].sum(skipna=True),
    ]
})
fn_counts["pct_fn_pre"] = (fn_counts["n_fn_pre"] / len(df) * 100).round(2)
fn_counts["pct_fn_post"] = (fn_counts["n_fn_post"] / len(df) * 100).round(2)
display(fn_counts)
# Out:
#         lado  n_fn_pre  n_fn_post  pct_fn_pre  pct_fn_post
# 0    derecho        31          5       63.27        10.20
# 1  izquierdo        26          2       53.06         4.08

# %%
# Guardar Falsos negativos en archivo CSV
fn_counts.to_csv(RESULTS_TABLES / "falsos_negativos_vel.csv", index=False)

# %% [markdown]
# ## Rangos y reglas clínicas
#
# Conteo de outliers por columna (velocidad) en base a velocidad mínima y máxima definidas.
#
# > **Nota**: Ajustar o revisar rangos fisiológicos (cambiar `VEL_MIN`/`VEL_MAX` en config)

# %%
vel_cols = [c for c in df.columns if "_velocidad_" in c]  # motor y sensitivo
outlier_rows = []

for col in vel_cols:
    s = df[col]
    mask_low  = s.notna() & (s < VEL_MIN)
    mask_high = s.notna() & (s > VEL_MAX)
    outlier_rows.append({
        "col": col,
        "n_low": int(mask_low.sum()),
        "n_high": int(mask_high.sum()),
        "n_total_outliers": int(mask_low.sum() + mask_high.sum()),
        "pct_outliers": round((mask_low.sum() + mask_high.sum()) / s.notna().sum() * 100, 2) if s.notna().sum() > 0 else np.nan
    })

outliers_tbl = pd.DataFrame(outlier_rows).sort_values("n_total_outliers", ascending=False)
display(outliers_tbl.head(20))
# Out:
#                                                col  n_low  n_high  \
# 0                    pre_dch_motor_velocidad_total      0       0
# 1              pre_dch_motor_velocidad_segmentario      0       0
# 22           post_izq_sensitivo_velocidad_n_baxter      0       0
# 21  post_izq_sensitivo_velocidad_n_plantar_lateral      0       0
# 20   post_izq_sensitivo_velocidad_n_plantar_medial      0       0
# 19  post_dch_sensitivo_velocidad_n_calcaneo_medial      0       0
# 18           post_dch_sensitivo_velocidad_n_baxter      0       0
# 17  post_dch_sensitivo_velocidad_n_plantar_lateral      0       0
# 16   post_dch_sensitivo_velocidad_n_plantar_medial      0       0
# 15            post_izq_motor_velocidad_segmentario      0       0
# 14                  post_izq_motor_velocidad_total      0       0
# 13            post_dch_motor_velocidad_segmentario      0       0
# 12                  post_dch_motor_velocidad_total      0       0
# 11   pre_izq_sensitivo_velocidad_n_calcaneo_medial      0       0
# 10            pre_izq_sensitivo_velocidad_n_baxter      0       0
# 9    pre_izq_sensitivo_velocidad_n_plantar_lateral      0       0
# 8     pre_izq_sensitivo_velocidad_n_plantar_medial      0       0
# 7    pre_dch_sensitivo_velocidad_n_calcaneo_medial      0       0
# 6             pre_dch_sensitivo_velocidad_n_baxter      0       0
# 5    pre_dch_sensitivo_velocidad_n_plantar_lateral      0       0
#
#     n_total_outliers  pct_outliers
# 0                  0           0.0
# 1                  0           0.0
# 22                 0           0.0
# 21                 0           0.0
# 20                 0           0.0
# 19                 0           NaN
# 18                 0           0.0
# 17                 0           0.0
# 16                 0           0.0
# 15                 0           0.0
# 14                 0           0.0
# 13                 0           0.0
# 12                 0           0.0
# 11                 0           0.0
# 10                 0           0.0
# 9                  0           0.0
# 8                  0           0.0
# 7                  0           0.0
# 6                  0           0.0
# 5                  0           0.0

# %%
# Guardar outliers en csv (si hay)
count_outliers = outliers_tbl["n_total_outliers"].sum()
if (count_outliers > 0):
    print(f"Hay {count_outliers} outliers")
    outliers_tbl.to_csv(config.RESULTS_TABLES / "outliers_velocidad.csv", index=False)
else:
    print(f"No hay outliers")
# Out:
# No hay outliers

# %% [markdown]
# ## Consistencia binarios

# %%
# Verificar {0, 1, NA} en binarios. Mostrar valores distintos si existen
bad_values = {}

for col in BINARY_COLS:
    if col in df.columns:
        uniques = set(df[col].dropna().unique().tolist())
        invalid = [v for v in uniques if v not in (0,1)]
        if invalid:
            bad_values[col] = invalid

bad_values  # {} si todo OK
# Out:
# {}

# %% [markdown]
# ## Guardar dataset procesado y resumen QA

# %%
# Guardar CSV
df.to_csv(DATA_PROCESSED_PATH / "data-neuro-tss.csv", index=False)
print("Guardado: /data/processed/data-neuro-tss.csv")
# print(f"Guardado: {DATA_PROCESSED_PATH}/data-neuro-tss.csv")
# Out:
# Guardado: /data/processed/data-neuro-tss.csv

# %%
# Exportar diccionario breve en results/summary_qa.md con bullets de issues detectados
summary_lines = []

summary_lines.append(f"# Resumen QA — {CSV_NAME}\n")
summary_lines.append(f"- **Shape**: {df.shape[0]} filas × {df.shape[1]} columnas")
summary_lines.append(f"- **Pacientes únicos (id)**: {df['id'].nunique()}")
summary_lines.append(f"- **IDs duplicados**: {n_ids_duplicated} (filas afectadas: {n_rows_dup_id})\n")

# Missing top-10
top_missing = missing_tbl.head(20).reset_index().rename(columns={"index":"col"})
summary_lines.append("## Top-20 columnas con más missing")
for _, r in top_missing.iterrows():
    summary_lines.append(f"- {r['col']}: {r['pct_missing']}%")

# Falsos negativos
summary_lines.append("\n## H2 — Posibles falsos negativos")
summary_lines.append("\n### Pre cirugía")
for _, r in fn_counts.iterrows():
    summary_lines.append(f"- {r['lado']}: n={int(r['n_fn_pre'])} ({r['pct_fn_pre']}%)")

summary_lines.append("\n## Post cirugía")
for _, r in fn_counts.iterrows():
    summary_lines.append(f"- {r['lado']}: n={int(r['n_fn_post'])} ({r['pct_fn_post']}%)")

# Outliers (velocidad)
summary_lines.append("\n## Outliers en velocidad (rango usado: "
                     f"{VEL_MIN}–{VEL_MAX} m/s; ajustable)")

if (count_outliers > 0):
    top_out = outliers_tbl.head(10).to_dict("records")
    for r in top_out:
        summary_lines.append(f"- {r['col']}: n_out={r['n_total_outliers']} "
                             f"(low={r['n_low']}, high={r['n_high']}, "
                             f"{r['pct_outliers']}% de válidos)")
else:
    summary_lines.append("- No se detectaron outliers.")

# Binarios
summary_lines.append("\n## Consistencia de binarios")
if bad_values:
    for col, vals in bad_values.items():
        summary_lines.append(f"- {col}: valores no válidos {vals}")
else:
    summary_lines.append("- OK (solo {0,1,NA})")

# Fechas
if "pre_fecha" in df.columns and "post_fecha" in df.columns:
    dias = (df["post_fecha"] - df["pre_fecha"]).dt.days
    n_neg = int((dias < 0).sum())
    summary_lines.append("\n## Fechas")
    summary_lines.append(f"- Días entre pre y post: n={dias.notna().sum()}, "
                         f"mediana={np.nanmedian(dias)}, IQR≈({np.nanpercentile(dias,25)}, {np.nanpercentile(dias,75)})")
    summary_lines.append(f"- Semanas entre pre y post: n={dias.notna().sum()}, "
                         f"mediana={round(np.nanmedian(dias / 7), 2)}, IQR≈({round(np.nanpercentile(dias / 7,25), 2)}, {round(np.nanpercentile(dias / 7,75), 2)})")
    summary_lines.append(f"- Casos con post < pre: {n_neg}")

# Guardar markdown
summary_md = "\n".join(summary_lines)
with open(RESULTS_PATH / "summary_qa.md", "w", encoding="utf-8") as f:
    f.write(summary_md)

print("Guardado: /results/summary_qa.md")
# print(f"Guardado: {RESULTS_PATH}/summary_qa.md")
# Out:
# Guardado: /results/summary_qa.md
